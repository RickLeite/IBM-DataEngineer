# %%
# %load_ext sql

# %%
import pandas as pd
import sqlite3

# %%
con = sqlite3.connect("FinalDB.db")
cur = con.cursor()

# %%
census_data_df = pd.read_csv('./data/ChicagoCensusData.csv')
census_data_df.head(3)
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
#
#    PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
#
#    PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# 0                                          18.2
# 1                                          20.8
# 2                                          11.8
#
#    PERCENT_AGED_UNDER_18_OR_OVER_64  PER_CAPITA_INCOME  HARDSHIP_INDEX
# 0                              27.5              23939            39.0
# ...

# %%
chicago_public_schools_df = pd.read_csv('./data/ChicagoPublicSchools.csv')
chicago_public_schools_df.head(3)
# Out:
#    School_ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
#
#   Elementary, Middle, or High School         Street_Address     City State  \
# 0                                 ES        615 W Kemper Pl  Chicago    IL
# 1                                 ES  7511 S South Shore Dr  Chicago    IL
# 2                                 ES     8010 S Kostner Ave  Chicago    IL
#
#    ZIP_Code    Phone_Number  \
# 0     60614  (773) 534-5720
# 1     60649  (773) 535-6650
# 2     60652  (773) 535-2280
#
#                                                 Link  \
# 0  http://schoolreports.cps.edu/SchoolProgressRep...
# 1  http://schoolreports.cps.edu/SchoolProgressRep...
# 2  http://schoolreports.cps.edu/SchoolProgressRep...
#
# ...

# %%
chicago_crime_data_df = pd.read_csv('./data/ChicagoCrimeData.csv')
chicago_crime_data_df.head(3)
# Out:
#         ID CASE_NUMBER        DATE                     BLOCK IUCR  \
# 0  3512276    HK587712  2004-08-28        047XX S KEDZIE AVE  890
# 1  3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE  820
# 2  8002131    HT233595  2011-04-04        043XX S WABASH AVE  820
#
#   PRIMARY_TYPE     DESCRIPTION          LOCATION_DESCRIPTION  ARREST  \
# 0        THEFT   FROM BUILDING            SMALL RETAIL STORE   False
# 1        THEFT  $500 AND UNDER                         OTHER   False
# 2        THEFT  $500 AND UNDER  NURSING HOME/RETIREMENT HOME   False
#
#    DOMESTIC  ...  DISTRICT  WARD  COMMUNITY_AREA_NUMBER  FBICODE X_COORDINATE  \
# 0     False  ...         9  14.0                   58.0        6    1155838.0
# 1     False  ...        11  27.0                   23.0        6    1152206.0
# 2     False  ...         2   3.0                   38.0        6    1177436.0
#
#    Y_COORDINATE  YEAR   LATITUDE  LONGITUDE                       LOCATION
# ...

# %%
# %sql sqlite:///FinalDB.db

# %%
# Load CENSUS_DATA table
# %sql DROP TABLE IF EXISTS CENSUS_DATA;
census_data_df.to_sql("CENSUS_DATA", con, method='multi')
# Out:
#  * sqlite:///FinalDB.db
# Done.
# 78

# %%
# %sql SELECT * FROM census_data LIMIT 3;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(0, 1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0),
#  (1, 2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0),
#  (2, 3.0, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20.0)]

# %%
# Load CHICAGO_PUBLIC_SCHOOLS table
# %sql DROP TABLE IF EXISTS CHICAGO_PUBLIC_SCHOOLS;
chicago_public_schools_df.to_sql("CHICAGO_PUBLIC_SCHOOLS", con, method='multi')
# Out:
#  * sqlite:///FinalDB.db
# Done.
# 566

# %%
# %sql SELECT * FROM CHICAGO_PUBLIC_SCHOOLS LIMIT 3;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(0, 610038, 'Abraham Lincoln Elementary School', 'ES', '615 W Kemper Pl', 'Chicago', 'IL', 60614, '(773) 534-5720', 'http://schoolreports.cps.edu/SchoolProgressReport_Eng/Spring2011Eng_610038.pdf', 'Fullerton Elementary Network', 'NORTH-NORTHWEST SIDE COLLABORATIVE', 'No', 'Standard', 'Not on Probation', 'Level 1', 'Yes', 'Very Strong', 99.0, 'Very Strong', '99', 'Strong', 74.0, 'Strong', 66.0, 'Weak', '65', 'Strong', '70', 'Strong', '56', 'Average', '47', '96.00%', 2.0, '96.40%', '95.80%', '80.1', '43.3', '89.6', '84.9', '60.7', '62.6', '81.9', '85.2', '52', '62.4', '66.3', '77.9', 69.7, 64.4, 0.2, 0.9, 'Yellow', 'Green', '67.1', '54.5', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 813, 33, 'NDA', 1171699.458, 1915829.428, 41.92449696, -87.64452163, 7, 'LINCOLN PARK', 43, 18, '(41.92449696, -87.64452163)'),
# ...

# %%
# Load CHICAGO_CRIME_DATA table
# %sql DROP TABLE IF EXISTS CHICAGO_CRIME_DATA;
chicago_crime_data_df.to_sql("CHICAGO_CRIME_DATA", con, method='multi')
# Out:
#  * sqlite:///FinalDB.db
# Done.
# 533

# %%
# %sql SELECT * FROM CHICAGO_CRIME_DATA LIMIT 3;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(0, 3512276, 'HK587712', '2004-08-28', '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 0, 0, 911, 9, 14.0, 58.0, '6', 1155838.0, 1873050.0, 2004, 41.8074405, -87.70395585, '(41.8074405, -87.703955849)'),
#  (1, 3406613, 'HK456306', '2004-06-26', '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 0, 0, 1112, 11, 27.0, 23.0, '6', 1152206.0, 1906127.0, 2004, 41.89827996, -87.71640551, '(41.898279962, -87.716405505)'),
#  (2, 8002131, 'HT233595', '2011-04-04', '043XX S WABASH AVE', '820', 'THEFT', '$500 AND UNDER', 'NURSING HOME/RETIREMENT HOME', 0, 0, 221, 2, 3.0, 38.0, '6', 1177436.0, 1876313.0, 2011, 41.81593313, -87.62464213, '(41.815933131, -87.624642127)')]

# %% [markdown]
# ----

# %% [markdown]
# ### Problem 1
#
# ##### Find the total number of crimes recorded in the CRIME table.

# %%
# %%sql
#     SELECT count(1) as n_of_crimes
#     FROM CHICAGO_CRIME_DATA
#     LIMIT 3;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(533,)]

# %% [markdown]
# ### Problem 2
#
# ##### List community areas with per capita income less than 11000.

# %%
# %%sql
#     SELECT COUNT(*)
#     FROM census_data
#     WHERE PER_CAPITA_INCOME < 11000;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(4,)]

# %% [markdown]
# ### Problem 3
#
# ##### List all case numbers for crimes  involving minors?(children are not considered minors for the purposes of crime analysis)

# %%
# %%sql
#     SELECT *
#     FROM CHICAGO_CRIME_DATA
#     WHERE LOWER(DESCRIPTION) LIKE '%minor%'
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(514, 3987219, 'HL266884', '2005-03-31', '024XX N CLARK ST', '2210', 'LIQUOR LAW VIOLATION', 'SELL/GIVE/DEL LIQUOR TO MINOR', 'CONVENIENCE STORE', 1, 0, 2333, 19, 43.0, 7.0, '22', 1172680.0, 1916483.0, 2005, 41.92626872, -87.64089934, '(41.926268719, -87.640899336)'),
#  (515, 3266814, 'HK238408', '2004-03-13', '093XX S STONY ISLAND AVE', '2230', 'LIQUOR LAW VIOLATION', 'ILLEGAL CONSUMPTION BY MINOR', 'ALLEY', 1, 0, 413, 4, 8.0, 48.0, '22', 1188539.0, 1843379.0, 2004, 41.72530099, -87.58496589, '(41.72530099, -87.584965887)')]

# %% [markdown]
# ### Problem 4
#
# ##### List all kidnapping crimes involving a child?

# %%
# %%sql
#     SELECT *
#     FROM CHICAGO_CRIME_DATA
#     WHERE PRIMARY_TYPE = 'KIDNAPPING' AND DESCRIPTION LIKE '%CHILD%'
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(520, 5276766, 'HN144152', '2007-01-26', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %% [markdown]
# ### Problem 5
#
# ##### What kinds of crimes were recorded at schools?

# %%
# %%sql
#     SELECT PRIMARY_TYPE, DESCRIPTION
#     FROM CHICAGO_CRIME_DATA
#     WHERE LOCATION_DESCRIPTION LIKE '%SCHOOL%'
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('BATTERY', 'SIMPLE'),
#  ('BATTERY', 'PRO EMP HANDS NO/MIN INJURY'),
#  ('BATTERY', 'SIMPLE'),
#  ('BATTERY', 'SIMPLE'),
#  ('BATTERY', 'SIMPLE'),
#  ('CRIMINAL DAMAGE', 'TO VEHICLE'),
#  ('NARCOTICS', 'POSS: HEROIN(WHITE)'),
#  ('NARCOTICS', 'MANU/DEL:CANNABIS 10GM OR LESS'),
#  ('ASSAULT', 'PRO EMP HANDS NO/MIN INJURY'),
#  ('CRIMINAL TRESPASS', 'TO LAND'),
#  ('PUBLIC PEACE VIOLATION', 'BOMB THREAT'),
#  ('PUBLIC PEACE VIOLATION', 'BOMB THREAT')]

# %% [markdown]
# ### Problem 6
#
# ##### List the average safety score for each type of school.

# %%
# %%sql
# SELECT
#     CASE
#         WHEN "Elementary, Middle, or High School" = 'ES' THEN 'Elementary School'
#         WHEN "Elementary, Middle, or High School" = 'HS' THEN 'High School'
#         WHEN "Elementary, Middle, or High School" = 'MS' THEN 'Middle School'
#     END AS "School Type",
#     Safety_Icon,
#     ROUND(AVG(SAFETY_SCORE), 2) AS Average_Safety_Score
# FROM CHICAGO_PUBLIC_SCHOOLS
# GROUP BY "Elementary, Middle, or High School"
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Elementary School', 'Very Strong', 49.52),
#  ('High School', 'Average', 49.62),
#  ('Middle School', 'Strong', 48.0)]

# %% [markdown]
# ### Problem 7
#
# ##### List 5 community areas with highest % of households below poverty line

# %%
# %%sql
#     SELECT
#         COMMUNITY_AREA_NAME,
#         PERCENT_HOUSEHOLDS_BELOW_POVERTY
#     FROM census_data
#     GROUP BY COMMUNITY_AREA_NAME
#     ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC
#         LIMIT 5
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %% [markdown]
# ### Problem 8
#
# ##### Which community area is most crime prone?

# %% [markdown]
# I am finding the community in which is crime prone by analysing the last 4 years of crimes, and not the one with more crimes in the whole dataset.

# %% [markdown]
# ### Problem 9
#
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %%
# %%sql
#     SELECT
#         COMMUNITY_AREA_NAME, hardship_index
#     FROM
#         CENSUS_DATA
#     WHERE
#         COMMUNITY_AREA_NUMBER = (
#             SELECT
#                 COMMUNITY_AREA_NUMBER
#             FROM
#                 CENSUS_DATA
#             ORDER BY
#                 hardship_index DESC
#             LIMIT 1
#         )
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale', 98.0)]

# %% [markdown]
# ### Problem 10
#
# ##### Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %%sql
# SELECT
#     subquery.COMMUNITY_AREA_NAME AS 'Most crime area',
#     subquery.CRIMES
# FROM
#     (
#         SELECT
#             COMMUNITY_AREA_NAME,
#             COUNT(*) AS CRIMES
#         FROM
#             CENSUS_DATA c
#         JOIN
#             CHICAGO_CRIME_DATA cd ON c.COMMUNITY_AREA_NUMBER = cd.COMMUNITY_AREA_NUMBER
#         GROUP BY
#             COMMUNITY_AREA_NAME
#         ORDER BY
#             COUNT(*) DESC
#         LIMIT 1
#     ) AS subquery
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Austin', 43)]
